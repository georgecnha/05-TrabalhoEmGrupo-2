# %%
print(18 * '=', 'Implementação de Métodos Numéricos: Resolução de Sistemas Lineares', 18 * '=')
print("""Alunos: George Pontes da Cunha
        Iago Sousa Bezerra de Menezes
        Gabriela Firmino Paz
        Sabrina Salomão de Souza""")

#===============================DEFINIÇÃO DA INVERSA E OUTRAS COISAS DE USO GERAL ======================================= 
def inversa(A):
    '''
    Executa o método de Gauss-Jordan para calcular a matriz inversa de A.
    Parâmetros de entrada: A é uma matriz quadrada de ordem n.
    Saída: Inv é a matriz inversa de A.
    '''
    # ESCREVA SEU CODIGO AQUI
    Inv = identidade(n)
    for k in range(0,n):
        ######### DIVIDE PELO PIVÔ ###############
        for j in range(k+1,n):
            A[k][j] = A [k][j]/A[k][k]
        for j in range(0, n):    
            Inv[k][j] = Inv[k][j]/A[k][k] 
        A[k][k] = 1
        ######## TERMINA DIVIDE PELO PIVÔ#########
        
        for i in range(0,n):
            if i != k:
                m= A[i][k]/A[k][k]
                for j in range(0,n):
                    A[i][j] = A[i][j] - m* A[k][j]
                    Inv[i][j] = Inv[i][j] - m* Inv[k][j]
                A[i][k] = 0
    return Inv
#========================================================================================================================
def identidade (n): #Cria Matriz identidade
    I=[]
    for i in range (n):
        linha=[]
        for j in range (n):
            if j==i:
                linha += [1]
            else:
                linha += [0]
        I+=[linha]
   
    return (I)
#=======================================================================================================================
def printM (M):   #Imprime Matriz
    for i in range (n):
        print (M[i])
        
def printM2 (M):   #Imprime Matriz
    for i in range (n):
        print ('[{}]'.format(M[i]))               
#======================================================================================================================
               
def recebeA(n):
    A=[]
    print('Os elementos da matriz são chamados a[i][j], sendo i as linhas e j as colunas.')
    for i in range (n):
        linha=[]
        for j in range (n):
            a=float(input('Insira o valor de a[{}][{}]: '.format(i+1,j+1)))
            linha.append(a)
        A+=[linha]
    return(A)
#========================================================================================================================
def recebeB(n):
    B=[]
    print('Os elementos da matriz são chamados b[i], sendo i as linhas.')
    for i in range (0,n):
        a=float(input('Insira o valor de b[{}]: '.format(i+1)))
        B+=[a]
    return(B)
#========================================================================================================================

def norma(v,x):
    """Calcula a norma entre dois vetores v e x.
    """
    # ESCREVA SEU CODIGO AQUI
    maxNum = 0
    maxDen = 0
    for i in range (0,n):
        if abs(v[i] - x[i]) > maxNum:
            maxNum = abs (v[i] - x[i])
        if abs(v[i]) > maxDen:
            maxDen = abs(v[i])
    return (maxNum/maxDen)
#===================================MÉTODO DE GAUSS-JACOBI===============================================================

def jacobi(A, b, x, epsilon, iterMax=50):
    """Resolve o sistema linear Ax=b usando o método iterativo Gauss-Jacobi.
    O critério de parada utiliza a norma-infinito.
    Saída é o vetor x.
    """
    # ESCREVA SEU CÓDIGO AQUI 
    v = n * [0]    
    C = [[0 for i in range(n)] for i in range(n)] ############Matriz Vazia=============
    for i in range(0,n):            
        for j in range(0,n):   #########Criando uma matriz de multiplicadores
            if (i==j):
                C[i][i] = 0
            else:
                C[i][j] = A[i][j]/A[i][i]  
    cont = 0
    while(cont<iterMax):
        for i in range(0,n):
            sum = 0      
            for j in range(0,n):
                sum = sum - C[i][j]*x[j]
            v[i] = b[i]/A[i][i] + sum
        if (norma(v,x)<=epsilon):
            return v
        for i in range(0,n):
            x[i] = v[i]
        cont+=1
    print("Erro: 50 iterações foram feitas!")
    return(v)
#==================================MÉTODO DE GAUSS-SEIDEL=======================================================

def seidel(A, b, epsilon, iterMax=50):
    """Resolve o sistema linear Ax=b usando o método iterativo Gauss-Seidel.
    O critério de parada utiliza a norma-infinito.
    Saída é o vetor x.
    
    """
    # ESCREVA SEU CODIGO AQUI
    x = n * [0]
    v = n * [0]
    a = n * [0]
    C = [[0 for i in range (n)] for i in range (n)]
    for i in range (0,n):
        for j in range (0,n):
            if (i == j):
                C[i][j] = 0
            else:
                C[i][j] = A[i][j]/A[i][i]       
    aux = 0
    while(aux < iterMax):
        for i in range (0,n):
            a[i] = x[i]
            soma = 0               
            for j in range (0,n):
                soma = soma - C[i][j]*x[j]                
            v[i]= b[i]/A[i][i] + soma
            x[i] = v[i]             
        if (norma(v,a)<=epsilon):
            return v
        aux+=1
    print("Número máximo de iterações!")
    return v

#============================================================================================
#============================================================================================
#=====================================MENU PRINCIPAL=========================================

e=float(input('Digite a tolerância a ser utilizada em ambos os métodos: '))
print('')

n=int(input('Digite a ordem das matrizes A: '))

print('Agora serão inseridos dos valores iniciais para d, utilizados em ambos os métodos: ')
D0=[]
for b in range(0, n):  # Insere os valores na lista
            D0+= [float(input('Digite o {}º valor para d0: '.format(b + 1)))]       
print('')  # Imprimindo uma string vazia por motivos estéticos





Onmenu = True
while Onmenu == True:

    # Opções do menu
    op = int(input("""Nosso sistema calculará sua matriz inversa (se existir) 
e a solução do seu sistema (se existir).
    
    Escolha um método para a solução do seu sistema e digite o número correspondente.

    1 - Método de Gauss-Jacobi
    2 - Método de Gauss-Seidel.
    10 - Sair do programa.

    Digite sua opção: """))

    # Executa opcao.
    if op == 1:
        print('Escolheu a opção 1: Método de Gauss-Jacobi.')
        nsists = int(input('Digite quantidade de sistemas a serem resolvidos: '))
        S = []  # Cria uma lista de Matrizes
        SB= []
        print('')
        for k in range(0, nsists):  # Uma lista de Matrizes
            print('A matriz A{} será inserida'.format(k+1))
            S+=[recebeA](n)
            print('')        
            print('')
            print('A matriz B{} será inserida'.format(k+1))
            SB+=[recebeB](n)
            print('')        
            print('')

        print(30 * '=', 'Entradas e Resultados', 30 * '=')
        for k in range(0, nsists):
            inv=[inversa(S[k])]
            Sol=[jacobi(S[k], SB[k], D0, e, iterMax=50)] # Chama a função para todos os valores da lista
            print('Para o {}º sistema temos:')
            print('A{}: '.format(k+1))
            printM(S[k])
            print('')
            print('B{}: '.format(k+1))
            printM2(SB[k])
            print('')
            print('D: ')
            printM2(Sol)
            print('')
            print('Inv: ')
            printM(inv)
            
            
    elif op == 2:
        print('Escolheu opção 2: Método de Newton Modificado.')
        n = int(input('Digite quantidade de valores iniciais para a: '))
        A = [None] * n  # Cria a lista de valores para A
        for b in range(0, n):  # Insere os valores na lista
            k = float(input('Digite o valor de A{}: '.format(b + 1)))
            A[b] = k

        D0 = [None] * n  # Cria a lista de valores para D
        for b in range(0, n):  # Insere os valores na lista
            j = float(input('Digite o {}º valor para d0: '.format(b + 1)))
            D0[b] = j
        print('')  # Imprimindo uma string vazia pro motivos estéticos
        print(30 * '=', 'Entradas e Resultados', 30 * '=')
        for b in range(0, n):
            nm(A[b], D0[b])
 
    elif op == 10:
        print('Escolheu Sair.')
        Onmenu = False
# Out:
# ================== Implementação de Métodos Numéricos: Resolução de Sistemas Lineares ==================
# Alunos: George Pontes da Cunha
#         Iago Sousa Bezerra de Menezes
#         Gabriela Firmino Paz
#         Sabrina Salomão de Souza
# Digite a tolerância a ser utilizada em ambos os métodos: 0.05
#
# Digite a ordem das matrizes A: 3
# Agora serão inseridos dos valores iniciais para d, utilizados em ambos os métodos:
# Digite o 1º valor para d0: 0
# Digite o 2º valor para d0: 0
# Digite o 3º valor para d0: 0
#
# Nosso sistema calculará sua matriz inversa (se existir)
# e a solução do seu sistema (se existir).
#
#     Escolha um método para a solução do seu sistema e digite o número correspondente.
#
#     1 - Método de Gauss-Jacobi
#     2 - Método de Gauss-Seidel.
#     10 - Sair do programa.
#
#     Digite sua opção: 1
# Escolheu a opção 1: Método de Gauss-Jacobi.
# Digite quantidade de sistemas a serem resolvidos: 1
#
# A matriz A1 será inserida
# Os elementos da matriz são chamados a[i][j], sendo i as linhas e j as colunas.
# Insira o valor de a[1][1]: 10
# Insira o valor de a[1][2]: 2
# Insira o valor de a[1][3]: 1
# Insira o valor de a[2][1]: 1
# Insira o valor de a[2][2]: 5
# Insira o valor de a[2][3]: 1
# Insira o valor de a[3][1]: 2
# Insira o valor de a[3][2]: 3
# Insira o valor de a[3][3]: 10
#
#
# A matriz B1 será inserida
# Os elementos da matriz são chamados b[i], sendo i as linhas.
# Insira o valor de b[1]: 7
# Insira o valor de b[2]: -8
# Insira o valor de b[3]: 6
#
#
# ============================== Entradas e Resultados ==============================
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-204835886c49> in <module>()
#     203         print(30 * '=', 'Entradas e Resultados', 30 * '=')
#     204         for k in range(0, nsists):
# --> 205             inv=[inversa(S[k])]
#     206             Sol=[jacobi(S[k], SB[k], D0, e, iterMax=50)] # Chama a função para todos os valores da lista
#     207             print('Para o {}º sistema temos:')
#
# <ipython-input-9-204835886c49> in inversa(A)
#      17         ######### DIVIDE PELO PIVÔ ###############
#      18         for j in range(k+1,n):
# ---> 19             A[k][j] = A [k][j]/A[k][k]
#      20         for j in range(0, n):
#      21             Inv[k][j] = Inv[k][j]/A[k][k]
#
# TypeError: 'float' object is not subscriptable

# %%
def jacobi(A, b, x, epsilon, iterMax=50):
    """Resolve o sistema linear Ax=b usando o método iterativo Gauss-Jacobi.
    O critério de parada utiliza a norma-infinito.
    Saída é o vetor x.
    """
    # ESCREVA SEU CÓDIGO AQUI 
    v = n * [0]    
    C = [[0 for i in range(n)] for i in range(n)] ############Matriz Vazia=============
    for i in range(0,n):            
        for j in range(0,n):   #########Criando uma matriz de multiplicadores
            if (i==j):
                C[i][i] = 0
            else:
                C[i][j] = A[i][j]/A[i][i]  
    cont = 0
    while(cont<iterMax):
        for i in range(0,n):
            sum = 0      
            for j in range(0,n):
                sum = sum - C[i][j]*x[j]
            v[i] = b[i]/A[i][i] + sum
        if (norma(v,x)<=epsilon):
            return v
        for i in range(0,n):
            x[i] = v[i]
        cont+=1
    print("Erro: 50 iterações foram feitas!")
    return(v)

A=[[10,2,1],
   [1,5,1],
   [2,3,10]]

B=[7,-8,6]

d=[0,0,0]

e=0.05

jacobi(A,B,d,e, iterMax=50)
# Out:
# [0.9994, -1.9888000000000001, 0.9984]
